# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AirQuality.csv")

# %%
df
# Out:
#       Index      Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0         1  10/03/04  18.00.00       2          NaN       NaN       NaN
# 1         2  10/03/04  19.00.00       2       1292.0     112.0       9.0
# 2         3  10/03/04  20.00.00       2          NaN       NaN       NaN
# 3         4  10/03/04  21.00.00       2          NaN       NaN       NaN
# 4         5  10/03/04  22.00.00       1          NaN       NaN       NaN
# ...     ...       ...       ...     ...          ...       ...       ...
# 9352   9353  04/04/05  10.00.00       3          NaN       NaN       NaN
# 9353   9354  04/04/05  11.00.00       2          NaN       NaN       NaN
# 9354   9355  04/04/05  12.00.00       2          NaN       NaN       NaN
# 9355   9356  04/04/05  13.00.00       2          NaN       NaN       NaN
# 9356   9357  04/04/05  14.00.00       2          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Index      Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0         1  10/03/04  18.00.00       2          NaN       NaN       NaN
# 1         2  10/03/04  19.00.00       2       1292.0     112.0       9.0
# 2         3  10/03/04  20.00.00       2          NaN       NaN       NaN
# 3         4  10/03/04  21.00.00       2          NaN       NaN       NaN
# 4         5  10/03/04  22.00.00       1          NaN       NaN       NaN
# ...     ...       ...       ...     ...          ...       ...       ...
# 9352   9353  04/04/05  10.00.00       3          NaN       NaN       NaN
# 9353   9354  04/04/05  11.00.00       2          NaN       NaN       NaN
# 9354   9355  04/04/05  12.00.00       2          NaN       NaN       NaN
# 9355   9356  04/04/05  13.00.00       2          NaN       NaN       NaN
# 9356   9357  04/04/05  14.00.00       2          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# Index               0
# Date                0
# Time                0
# CO(GT)              0
# PT08.S1(CO)      7220
# NMHC(GT)         7220
# C6H6(GT)         7220
# PT08.S2(NMHC)    9357
# NOx(GT)          9357
# PT08.S3(NOx)     9357
# NO2(GT)          9357
# PT08.S4(NO2)     9357
# PT08.S5(O3)      9357
# T                9357
# RH               9357
# AH               9357
# dtype: int64

# %%
df1 = pd.read_csv('AirQuality.csv')
df2 = pd.read_csv('heart.csv')
    
merged_df = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
merged_df
# Out:
#        Index      Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0          1  10/03/04  18.00.00     2.0          NaN       NaN       NaN
# 1          2  10/03/04  19.00.00     2.0       1292.0     112.0       9.0
# 2          3  10/03/04  20.00.00     2.0          NaN       NaN       NaN
# 3          4  10/03/04  21.00.00     2.0          NaN       NaN       NaN
# 4          5  10/03/04  22.00.00     1.0          NaN       NaN       NaN
# ...      ...       ...       ...     ...          ...       ...       ...
# 10377   1021       NaN       NaN     NaN          NaN       NaN       NaN
# 10378   1022       NaN       NaN     NaN          NaN       NaN       NaN
# 10379   1023       NaN       NaN     NaN          NaN       NaN       NaN
# 10380   1024       NaN       NaN     NaN          NaN       NaN       NaN
# 10381   1025       NaN       NaN     NaN          NaN       NaN       NaN
#
#        PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  ...   chol  fbs  restecg  \
# ...

# %%
df1 = pd.read_csv('AirQuality.csv')
df2 = pd.read_csv('heart.csv')
merged_dfm = pd.merge(df1, df2, on='Index', how='inner')

# %%
merged_dfm
# Out:
#       Index      Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0         1  10/03/04  18.00.00       2          NaN       NaN       NaN
# 1         2  10/03/04  19.00.00       2       1292.0     112.0       9.0
# 2         3  10/03/04  20.00.00       2          NaN       NaN       NaN
# 3         4  10/03/04  21.00.00       2          NaN       NaN       NaN
# 4         5  10/03/04  22.00.00       1          NaN       NaN       NaN
# ...     ...       ...       ...     ...          ...       ...       ...
# 1020   1021  22/04/04  06.00.00    -200        977.0    -200.0       5.0
# 1021   1022  22/04/04  07.00.00    -200       1234.0    -200.0      13.0
# 1022   1023  22/04/04  08.00.00    -200       1403.0    -200.0      21.0
# 1023   1024  22/04/04  09.00.00    -200       1538.0    -200.0      26.0
# 1024   1025  22/04/04  10.00.00    -200       1343.0    -200.0      20.0
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  ...  chol  fbs  restecg  thalach  \
# ...

# %%
df_filtered = merged_dfm[merged_dfm['age'] > 20]

# %%
df_filtered
# Out:
#       Index      Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0         1  10/03/04  18.00.00       2          NaN       NaN       NaN
# 1         2  10/03/04  19.00.00       2       1292.0     112.0       9.0
# 2         3  10/03/04  20.00.00       2          NaN       NaN       NaN
# 3         4  10/03/04  21.00.00       2          NaN       NaN       NaN
# 4         5  10/03/04  22.00.00       1          NaN       NaN       NaN
# ...     ...       ...       ...     ...          ...       ...       ...
# 1020   1021  22/04/04  06.00.00    -200        977.0    -200.0       5.0
# 1021   1022  22/04/04  07.00.00    -200       1234.0    -200.0      13.0
# 1022   1023  22/04/04  08.00.00    -200       1403.0    -200.0      21.0
# 1023   1024  22/04/04  09.00.00    -200       1538.0    -200.0      26.0
# 1024   1025  22/04/04  10.00.00    -200       1343.0    -200.0      20.0
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  ...  chol  fbs  restecg  thalach  \
# ...

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("heart.csv")

# creating bool series False for NaN values
bool_series = pd.notnull(data["heart"])

# displayed data only with team = NaN
data[bool_series]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'heart'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
