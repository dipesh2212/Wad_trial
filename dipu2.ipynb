# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/dipeshsonawane/Desktop/DSBDA DIPU/dataset_Facebook.csv')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1 = df[['Page total likes','Type','Category','Post Month','Post Weekday']]

# %%
df2 = df[['Page total likes','Lifetime Post Total Reach' ,'Lifetime Post Total Impressions','Lifetime Engaged Users','Lifetime Post Consumers','Lifetime Post Consumptions','Lifetime Post Impressions by people who have liked your Page']]

# %%
sorted_data  = df.sort_values(by= 'Page total likes', ascending= False)

# %%
sorted_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
sorted_data  = df.sort_values(by= 'Lifetime Post Consumptions', ascending= False)

# %%
df.shape
# Out:
# (500, 19)

# %%
pivot_table=pd.pivot_table(df,index=['Type','Paid'],values='like') #Used for aggregation and grouping to find analysis
pivot_table
# Out:
#                    like
# Type   Paid
# Link   0.0    79.562500
#        1.0    56.666667
# Photo  0.0   160.177049
#        1.0   240.882353
# Status 0.0   147.828571
#        1.0   277.800000
# Video  0.0   216.000000
#        1.0   243.000000

# %%
pivot_table.shape
# Out:
# (8, 1)

# %%
stacked_data = df.set_index(['Type', 'Paid']).stack()

# %%
stacked_data
# Out:
# Type   Paid
# Photo  0.0   Page total likes                                                       139441.0
#              Category                                                                    2.0
#              Post Month                                                                 12.0
#              Post Weekday                                                                4.0
#              Post Hour                                                                   3.0
#                                                                                       ...
#        NaN   Lifetime People who have liked your Page and engaged with your post       316.0
#              comment                                                                     0.0
#              like                                                                       91.0
#              share                                                                      28.0
# ...
