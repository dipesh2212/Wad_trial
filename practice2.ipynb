# %% [markdown]
# 2. Perform the following operations using Python on the Facebook metrics data sets
# a. Create data subsets
# b. SortData
# c. Shape and reshape Data

# %%
import pandas as pd

# %%
#load the datatset usinf pd.read_csv commmand
df = pd.read_csv('/Users/dipeshsonawane/Desktop/DSBDA DIPU/dataset_Facebook.csv')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df1= df[['Page total likes','Type'	,'Category', 'Post Month','Post Weekday','Post Hour','Paid']]
df1.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid
# 0   0.0
# 1   0.0
# 2   0.0
# 3   1.0
# 4   0.0

# %%
df2= df[['Page total likes','Lifetime Post Total Reach','Lifetime Post Total Impressions','Lifetime Engaged Users','Lifetime Post Consumers','Lifetime Post Consumptions']]
df2.head()
# Out:
#    Page total likes  Lifetime Post Total Reach  \
# 0            139441                       2752
# 1            139441                      10460
# 2            139441                       2413
# 3            139441                      50128
# 4            139441                       7244
#
#    Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                             5091                     178
# 1                            19057                    1457
# 2                             4373                     177
# 3                            87991                    2211
# 4                            13594                     671
#
#    Lifetime Post Consumers  Lifetime Post Consumptions
# 0                      109                         159
# 1                     1361                        1674
# 2                      113                         154
# 3                      790                        1119
# ...

# %%
#sort data

sorted_data = df.sort_values('Page total likes', ascending=False)
